# %%
cd ..
# Out:
# /Users/hidde/Documents/GitHub/ma-communicative-robots/projects/memory/notebooks

# %%
cd ..
# Out:
# /Users/hidde/Documents/GitHub/ma-communicative-robots/projects/memory

# %%
import json
from glob import glob
from tqdm.notebook import tqdm
import os
import random

from transformers import T5Tokenizer, T5ForConditionalGeneration

tokenizer = T5Tokenizer.from_pretrained("tscholak/t5.1.1.lm100k.base")
model = T5ForConditionalGeneration.from_pretrained("tscholak/t5.1.1.lm100k.base")


def read_json(path):
    """Read json file.

    Args
    ----
    path: path to the json

    Returns
    -------
    loaded: loaded dict

    """
    with open(path, "r") as stream:
        loaded = json.load(stream)

    return loaded

# %%
def convert_to_days(entry):
    entry = sorted(
    entry, key=lambda x: x[-1])
    for idx, mem in enumerate(entry):
        max_len = len(entry)
        days = len(entry) - idx - 1
        if days == 0:
            timestamp = "today"
        else:
            timestamp = f"{days} days ago"
        entry[idx][-1] = timestamp

# %%
path = "data/128_64.json"
data = read_json(path)
prompts = []
answers = []
prompt_counter = 0
for entry in data['val']:
    prompt_counter += 1
    print('prompt: ', prompt_counter)
    entry["episodic_memory_system"] = sorted(
    entry["episodic_memory_system"], key=lambda x: x[-1], reverse=True)
    convert_to_days(entry["episodic_memory_system"])
    
    prompt = []
    counter = 0
    for mem in entry["episodic_memory_system"]:
        prompt.append(f"{mem[0]} was at {mem[2]}, {mem[3]}.")
        counter += 1
    print('episodic counter', counter)
    counter = 0 
    for mem in entry["semantic_memory_system"]:
        prompt.append(f"{mem[0]} were found at {mem[2]}.")
        counter += 1
    print('sementic counter', counter)
    prompt.append(f"Where is {entry['question'][0]}?")
    prompt = ' '.join(prompt)
    prompts.append(prompt)
    answers.append(entry['correct_answer'])
# Out:
# prompt:  1
# episodic counter 1
# sementic counter 0
# prompt:  2
# episodic counter 2
# sementic counter 0
# prompt:  3
# episodic counter 3
# sementic counter 0
# prompt:  4
# episodic counter 4
# sementic counter 0
# prompt:  5
# episodic counter 5
# sementic counter 0
# prompt:  6
# episodic counter 6
# sementic counter 0
# prompt:  7
# episodic counter 7
# sementic counter 0
# prompt:  8
# episodic counter 8
# sementic counter 0
# prompt:  9
# episodic counter 9
# sementic counter 0
# prompt:  10
# episodic counter 10
# sementic counter 0
# prompt:  11
# episodic counter 11
# sementic counter 0
# prompt:  12
# episodic counter 12
# sementic counter 0
# prompt:  13
# episodic counter 13
# sementic counter 0
# prompt:  14
# episodic counter 14
# sementic counter 0
# prompt:  15
# episodic counter 15
# sementic counter 0
# prompt:  16
# episodic counter 16
# sementic counter 0
# prompt:  17
# episodic counter 17
# sementic counter 0
# prompt:  18
# episodic counter 18
# sementic counter 0
# prompt:  19
# episodic counter 19
# sementic counter 0
# prompt:  20
# episodic counter 20
# sementic counter 0
# prompt:  21
# episodic counter 21
# sementic counter 0
# prompt:  22
# episodic counter 22
# sementic counter 0
# prompt:  23
# episodic counter 23
# sementic counter 0
# prompt:  24
# episodic counter 24
# sementic counter 0
# prompt:  25
# episodic counter 25
# sementic counter 0
# prompt:  26
# episodic counter 26
# sementic counter 0
# prompt:  27
# episodic counter 27
# sementic counter 0
# prompt:  28
# episodic counter 28
# sementic counter 0
# prompt:  29
# episodic counter 29
# sementic counter 0
# prompt:  30
# episodic counter 30
# sementic counter 0
# prompt:  31
# episodic counter 31
# sementic counter 0
# prompt:  32
# episodic counter 32
# sementic counter 0
# prompt:  33
# episodic counter 33
# sementic counter 0
# prompt:  34
# episodic counter 34
# sementic counter 0
# prompt:  35
# episodic counter 35
# sementic counter 0
# prompt:  36
# episodic counter 36
# sementic counter 0
# prompt:  37
# episodic counter 37
# sementic counter 0
# prompt:  38
# episodic counter 38
# sementic counter 0
# prompt:  39
# episodic counter 39
# sementic counter 0
# prompt:  40
# episodic counter 40
# sementic counter 0
# prompt:  41
# episodic counter 41
# sementic counter 0
# prompt:  42
# episodic counter 42
# sementic counter 0
# prompt:  43
# episodic counter 43
# sementic counter 0
# prompt:  44
# episodic counter 44
# sementic counter 0
# prompt:  45
# episodic counter 45
# sementic counter 0
# prompt:  46
# episodic counter 46
# sementic counter 0
# prompt:  47
# episodic counter 47
# sementic counter 0
# prompt:  48
# episodic counter 48
# sementic counter 0
# prompt:  49
# episodic counter 49
# sementic counter 0
# prompt:  50
# episodic counter 50
# sementic counter 0
# prompt:  51
# episodic counter 51
# sementic counter 0
# prompt:  52
# episodic counter 52
# sementic counter 0
# prompt:  53
# episodic counter 53
# sementic counter 0
# prompt:  54
# episodic counter 54
# sementic counter 0
# prompt:  55
# episodic counter 55
# sementic counter 0
# prompt:  56
# episodic counter 56
# sementic counter 0
# prompt:  57
# episodic counter 57
# sementic counter 0
# prompt:  58
# episodic counter 58
# sementic counter 0
# prompt:  59
# episodic counter 59
# sementic counter 0
# prompt:  60
# episodic counter 60
# sementic counter 0
# prompt:  61
# episodic counter 61
# sementic counter 0
# prompt:  62
# episodic counter 62
# sementic counter 0
# prompt:  63
# episodic counter 63
# sementic counter 0
# prompt:  64
# episodic counter 64
# sementic counter 0
# prompt:  65
# episodic counter 58
# sementic counter 1
# prompt:  66
# episodic counter 59
# sementic counter 1
# prompt:  67
# episodic counter 60
# sementic counter 1
# prompt:  68
# episodic counter 61
# sementic counter 1
# prompt:  69
# episodic counter 62
# sementic counter 1
# prompt:  70
# episodic counter 63
# sementic counter 1
# prompt:  71
# episodic counter 64
# sementic counter 1
# prompt:  72
# episodic counter 59
# sementic counter 2
# prompt:  73
# episodic counter 60
# sementic counter 2
# prompt:  74
# episodic counter 61
# sementic counter 2
# prompt:  75
# episodic counter 62
# sementic counter 2
# prompt:  76
# episodic counter 63
# sementic counter 2
# prompt:  77
# episodic counter 64
# sementic counter 2
# prompt:  78
# episodic counter 60
# sementic counter 3
# prompt:  79
# episodic counter 61
# sementic counter 3
# prompt:  80
# episodic counter 62
# sementic counter 3
# prompt:  81
# episodic counter 63
# sementic counter 3
# prompt:  82
# episodic counter 64
# sementic counter 3
# prompt:  83
# episodic counter 60
# sementic counter 4
# prompt:  84
# episodic counter 61
# sementic counter 4
# prompt:  85
# episodic counter 62
# sementic counter 4
# prompt:  86
# episodic counter 63
# sementic counter 4
# prompt:  87
# episodic counter 64
# sementic counter 4
# prompt:  88
# episodic counter 59
# sementic counter 5
# prompt:  89
# episodic counter 60
# sementic counter 5
# prompt:  90
# episodic counter 61
# sementic counter 5
# prompt:  91
# episodic counter 62
# sementic counter 5
# prompt:  92
# episodic counter 63
# sementic counter 5
# prompt:  93
# episodic counter 64
# sementic counter 5
# prompt:  94
# episodic counter 60
# sementic counter 6
# prompt:  95
# episodic counter 61
# sementic counter 6
# prompt:  96
# episodic counter 62
# sementic counter 6
# prompt:  97
# episodic counter 63
# sementic counter 6
# prompt:  98
# episodic counter 64
# sementic counter 6
# prompt:  99
# episodic counter 60
# sementic counter 6
# prompt:  100
# episodic counter 61
# sementic counter 6
# prompt:  101
# episodic counter 62
# sementic counter 6
# prompt:  102
# episodic counter 63
# sementic counter 6
# prompt:  103
# episodic counter 64
# sementic counter 6
# prompt:  104
# episodic counter 60
# sementic counter 7
# prompt:  105
# episodic counter 61
# sementic counter 7
# prompt:  106
# episodic counter 62
# sementic counter 7
# prompt:  107
# episodic counter 63
# sementic counter 7
# prompt:  108
# episodic counter 64
# sementic counter 7
# prompt:  109
# episodic counter 61
# sementic counter 8
# prompt:  110
# episodic counter 62
# sementic counter 8
# prompt:  111
# episodic counter 63
# sementic counter 8
# prompt:  112
# episodic counter 64
# sementic counter 8
# prompt:  113
# episodic counter 61
# sementic counter 9
# prompt:  114
# episodic counter 62
# sementic counter 9
# prompt:  115
# episodic counter 63
# sementic counter 9
# prompt:  116
# episodic counter 64
# sementic counter 9
# prompt:  117
# episodic counter 60
# sementic counter 9
# prompt:  118
# episodic counter 61
# sementic counter 9
# prompt:  119
# episodic counter 62
# sementic counter 9
# prompt:  120
# episodic counter 63
# sementic counter 9
# prompt:  121
# episodic counter 64
# sementic counter 9
# prompt:  122
# episodic counter 61
# sementic counter 9
# prompt:  123
# episodic counter 62
# sementic counter 9
# prompt:  124
# episodic counter 63
# sementic counter 9
# prompt:  125
# episodic counter 64
# sementic counter 9
# prompt:  126
# episodic counter 61
# sementic counter 10
# prompt:  127
# episodic counter 62
# sementic counter 10
# prompt:  128
# episodic counter 63
# sementic counter 10

# %%
def predict(prompts):
    predictions = []
    for prompt in prompts:
        input_ids = tokenizer(prompt, return_tensors="pt").input_ids
        outputs = model.generate(input_ids)
        prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
        print(prediction)
        predictions.append(prediction)
    return predictions

# %%
def calculate_accuracy(answers, predictions):
    correct = 0
    wrong = 0
    for answer, pred in zip(answers, predictions):
        if answer in pred:
            correct += 1
        else:
            wrong += 1

    print(f"correct: {correct}\nwrong: {wrong}")
    print(f"accuracy is {correct / (correct+ wrong)*100}")

# %%
predictions = predict(prompts)
# Out:
# Mary's bench was at Mary's city, today. Where is Mary's bench
# Mary's bench was at Mary's city, 1 days ago. Where is Mary'
# The bench was at John's building, 2 days ago.
# Mary's person was at Mary's building, today. Linda's boat was at
# Mary's bench was at Mary's city, 5 days ago. Where is John'
# James's motorcycle was at James's garage, today. James's motorcycle was at
# James's car was at James's garage, 1 days ago. James's car
# John's car was at John's water, 7 days ago. Mary's car
# Mary's boat was at Mary's zoo, today. John's
# Mary's person was at Mary's building, 10 days ago. John's boat
# Mary's person was at Mary's building, 11 days ago. John's truck
# James's motorcycle was at John's garage, 12 days ago. James's motorcycle
# John's truck was at John's water, 13 days ago. John's motorcycle
# John's airplane was at John's sky, today. John's train was at
# John's car was at John's city, 15 days ago. John's car
# David's bicycle was at David's garage, 15 days ago. John's airplane
# David's bicycle was at David's garage, 17 days ago. John's car
# The train was at Linda's garden, 1 day ago. David's truck was at
# James's motorcycle was at James's city, 19 days ago. Mary's person
# John's bike was at John's sky, today. Linda's bike was at
# John's train was at John's sky, 21 days ago. John's motorcycle
# James's bicycle was at James's garage, today. John's bench was at
# John's boat was at John's water, 23 days ago. John's boat
# Linda's bicycle was at Linda's garage, 1 days ago. James's bicycle
# John's truck was at John's water, today. Linda's bicycle was at
# Linda's bus was at Linda's city, today. John's truck was at
# John's bus was at Linda's city, 27 days ago. Linda's bus
# The address of John's bench is at John's city, NE, USA.
# Linda's bus was at Linda's city, 29 days ago. Where is Linda'
# John's bike was at John's sky, 30 days ago. Linda's bicycle
# John's truck was at John's garage, 1 day ago. Mary's bicycle
# Mary's person was at Mary's building, 32 days ago. David's truck
# Token indices sequence length is longer than the specified maximum sequence length for this model (525 > 512). Running this sequence through the model will result in indexing errors
# Linda's bus was at Linda's city, 33 days ago. John's truck
# James's bicycle was at James's city, 34 days ago. Linda's bus
# John's train was at John's city, 35 days ago. John's train
# The boat was at John's city, 1 day ago. Linda's person was at
# The boat was at John's city, 37 days ago. John's boat was at
# James's bicycle was at James's city, 38 days ago. Linda's bench
# The address is a zoo in the city of Linda.
# The plane was at John's sky, 40 days ago. John's plane was at
# Mary's bike was at Linda's garden, 41 days ago. Mary's person
# Mary's person was at Mary's building, 42 days ago. David's truck
# David's bicycle was at David's garage, today. David's person was at
# Mary's person was at Mary's building, 44 days ago. David's truck
# Mary's person was at Mary's building, 45 days ago. David's truck
# Linda's bike was at Linda's zoo, 46 days ago. Mary
# The plane was at John's sky, 46 days ago. John's plane was at
# David's bicycle was at David's garage, 48 days ago. John's airplane
# David's bicycle was at David's garage, today. Mary's bicycle was at
# The address of Linda's motorcycle is at the address of the address of the address of the
# The boat was at John's city, 51 days ago. John's boat was at
# Linda's bench was at Linda's garden, today. David's motorcycle was at
# David's bike was at David's garage, 53 days ago. David's bike
# The bench was at Linda's garden, 53 days ago. Linda's bike was at
# David's boat was at David's water, 57 days ago. David's
# The bench was at Linda's garden, today. James's bus was at James'
# The address of Linda's bench is at Linda's garden, a little over
# The address of Linda's bicycle is at Linda's garage, 57 days ago.
# James's bus was at James's sky, 59 days ago. David's
# David's bike was at David's garage, 59 days ago. David's
# The bench was at Linda's garden, 59 days ago. Linda's bike was
# Mary's person was at Mary's building, 62 days ago. David's
# Mary's bicycle was at Mary's water, 63 days ago. Mary's
# Mary's plane was at Mary's sky, 63 days ago. Mary's
# Mary's car was at Mary's sky, 58 days ago. John's
# The car was found at garage. Where is John's car? The car was found at
# The bike was found at garage. Where is Linda's bench? The bike was found at
# David's motorcycle was found at garage. Where is David's motorcycle? David's
# The bike was found at garage. Where is Linda's bench? The bike was found at
# The address of Mary's bench is at Mary's city, 62 days ago.
# The bike was found at garage. Where is David's bicycle? The bike was found at
# David's motorcycle was found at water. motorcycle were found at garage. Where is David'
# - - - - - - - - -
# James's car was at James's city, 61 days ago. Mary's
# The train was at John's zoo, today. David's truck was
# The plane was found at Mary's sky, 63 days ago. Mary's person
# - John's boat was found at water. motorcycle were found at garage. Where is
# The plane was found at Mary's garden, 59 days ago. Mary's boat
# - - - - - - - - -
# David's truck was at David's garage, today. James's bus was at
# The car was found at John's sky, 63 days ago. John's plane
# The train was at Mary's city, 63 days ago. Mary's boat was
# The address of James's bench is at John's city, 59 days ago.
# The car was at James's city, 59 days ago. John's bus was
# The boat was found at Mary's zoo. The boat was found at Mary
# Mary's bus was at Mary's city, 63 days ago. Mary's
# Mary's plane was at Mary's city, 63 days ago. Mary's
# - David's motorcycle was found at David's garage. bicycle were found at garage
# The plane was found at Mary's city, 59 days ago. Mary's bike
# The bench was found at David's garden, today. Linda's train was at Linda
# - - - - - - - - -
# The car was found at John's garage. John's motorcycle was at John's
# - Mary's person was found at Mary's building. - Mary's
# The train was found at Mary's city, 59 days ago. David's bus
# The boat was found at John's water, today. David's bench was at David
# David's bike was at James's city, 61 days ago. David's
# David's bike was at James's city, 63 days ago. David's
# The boat was found at James's city, 63 days ago. David's motorcycle
# - - - - - - - - -
# David's bus was at James's sky, today. David's airplane was at
# James's motorcycle was found at sky. bicycle were found at garage. train were found at
# The boat was found at David's garage. The boat was found at John's city
# The boat was found at John's city, 63 days ago. John's boat
# - - - - - - - - -
# The following is a list of all the places where James's motorcycle was found.
# The plane was found at John's sky. John's car was at John's
# James's boat was found at James's city, 63 days ago. John'
# James's boat was at James's water, today. John's airplane was at
# The car was found at James's city, 61 days ago. John's car
# The bicycle was found at Mary's city, 61 days ago. John's truck
# James's truck was at James's city, 63 days ago. James's
# The bicycle was found at Mary's water, 63 days ago. John's truck
# The train was at David's sky, today. Mary's boat was at Mary'
# - - - - - - - - -
# David's person was at David's building, 63 days ago. David's
# - Linda's person was at Linda's building, today. - Linda'
# - Linda's train was at Linda's garden, 59 days ago.
# - - - - - - - - -
# - - - - - - - - -
# - - - - - - - - -
# The car was found at John's sky, 63 days ago. John's car
# The bus was found at John's sky, 59 days ago. John's bus
# - David's train was at David's sky, 61 days ago.
# The plane was found at David's garage. The plane was found at David's sky
# The car was at David's sky, today. David's car was at David'
# The car was found at Mary's city, 61 days ago. Mary's bike
# - Mary's person was at Mary's building, 61 days ago.
# - David's bicycle was at David's city, 63 days ago.

# %%
calculate_accuracy(answers, predictions)
# Out:
# correct: 69
# wrong: 59
# accuracy is 53.90625
