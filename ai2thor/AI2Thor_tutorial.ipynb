# %% [markdown]
# # Tutorial on AI2Thor
#
# AI2Thor is a virtual, interactive environment, which we will be using for the group project in this course. The functionality provided by AI2Thor includes for example moving around the environment, and accessing the metadata of objects in the current view.
#
# This tutorial is largely based on these two notebooks, which can also be useful for you to look at: \
# https://colab.research.google.com/github/allenai/ai2thor-colab/blob/main/templates/AI2_THOR_Full_Starter_Template.ipynb
#
# https://colab.research.google.com/drive/1Il6TqmRXOkzYMIEaOU9e4-uTDTIb5Q78

# %% [markdown]
# There are a lot of other things you can do in AI2Thor that are not mentioned in this tutorial, such as manipulate objects (e.g. open a fridge, slice an apple, move an object from A to B). You don't necessarily need to use any of these functionalities in your project, but if you are interested you can find more information in the documentation: https://ai2thor.allenai.org/ithor/documentation

# %% [markdown]
# ## Setup

# %%
#!pip install --upgrade ai2thor --quiet
#!pip install ai2thor-colab prior --upgrade &> /dev/null

# %% [markdown]
# To run AI2Thor on Google Colab, you need to install `xvfb` (not needed if you are running AI2Thor on your own computer):

# %%
#import os
#os.system('apt-get install xvfb')

# %% [markdown]
# We are using a dataset called "procthor-10k" which contains 12 thousand virtual houses. If you want to have a look at the paper about ProcThor, it's here: https://arxiv.org/abs/2206.06994

# %%
import prior

dataset = prior.load_dataset("procthor-10k")
dataset
# Out:
# Fetching reference HEAD
# [AI2-THOR WARNING] There has been an update to ProcTHOR-10K that must be used with AI2-THOR version 5.0+. To use the new version of ProcTHOR-10K, please update AI2-THOR to version 5.0+ by running:
#     pip install --upgrade ai2thor
# Alternatively, to downgrade to the old version of ProcTHOR-10K, run:
#    prior.load_dataset("procthor-10k", revision="ab3cacd0fc17754d4c080a3fd50b18395fae8647")
# Loading train: 100%|████████████████████| 10000/10000 [00:01<00:00, 6389.54it/s]
# Loading val: 100%|████████████████████████| 1000/1000 [00:00<00:00, 7044.05it/s]
# Loading test: 100%|███████████████████████| 1000/1000 [00:00<00:00, 6642.32it/s]
# DatasetDict(
#     train=Dataset(
#     dataset=procthor-dataset,
#     size=10000,
#     split=train
# ),
#     val=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=val
# ),
#     test=Dataset(
#     dataset=procthor-dataset,
#     size=1000,
#     split=test
# )
# )

# %% [markdown]
# The next cell is again only necessary if you are running this in Google Colab.

# %%
#import ai2thor_colab
#ai2thor_colab.start_xserver()

# %% [markdown]
# Let's choose an virtual house from the training set:

# %%
house = dataset["train"][15]

# %% [markdown]
# Next, we need to instantiate a controller:

# %%
from ai2thor.controller import Controller

# %%
controller = Controller(scene=house, visibilityDistance=2, width=750, height=750)

# %% [markdown]
# Now that we have instantiated a controller, we can start moving around!

# %% [markdown]
# ## Moving around

# %%
from PIL import Image
Image.fromarray(controller.last_event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x750>

# %%
controller.step("RotateLeft") # or "RotateLeft"
# Out:
# <ai2thor.server.Event at 0x116321210
#     .metadata["lastAction"] = RotateLeft
#     .metadata["lastActionSuccess"] = True
#     .metadata["errorMessage"] = "
#     .metadata["actionReturn"] = None
# >

# %% [markdown]
# When rotating around, you probably noticed that there are some object types that appear multiple times in this scene, e.g. multiple chairs, multiple paintings, multiple shelving units. This means that if you are in this room, and you for example refer to "the painting on the wall", you could be referring to either of the two paintings in the room. This type of ambiguity is something you'll need to find a way to deal with in your group project.

# %%
controller.step("MoveAhead") # or "MoveBack", "MoveLeft", "MoveRight"
# Out:
# <ai2thor.server.Event at 0x1163d2510
#     .metadata["lastAction"] = MoveAhead
#     .metadata["lastActionSuccess"] = True
#     .metadata["errorMessage"] = "
#     .metadata["actionReturn"] = None
# >

# %% [markdown]
# In your project, you may at some point want to teleport the robot to another random position in the house. To do this, you need to know which positions in the house are reachable (i.e. the robot can be in this position, which it for instance cannot if another object is already located there). The following code returns a list of all the "reachable positions":

# %%
event = controller.step(action="GetReachablePositions")
reachable_positions = event.metadata["actionReturn"]
event.metadata["actionReturn"]
# Out:
# [{'x': 9.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 10.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 10.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 11.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 10.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 11.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 10.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 12.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.0, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 11.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 0.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 1.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 0.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 1.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 0.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.5},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.5, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 1.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.25},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 1.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 3.0},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.5},
#  {'x': 2.0, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 2.25, 'y': 0.9009997844696045, 'z': 2.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 5.75},
#  {'x': 1.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 1.75, 'y': 0.9009997844696045, 'z': 2.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 1.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 2.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 1.0, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 4.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 6.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 0.75, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 4.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 0.5, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 4.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 0.25, 'y': 0.9009997844696045, 'z': 5.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 6.25, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 11.25},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 6.5, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 11.25},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 11.5},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 11.25},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 10.5},
#  {'x': 3.75, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 9.75, 'y': 0.9009997844696045, 'z': 7.0},
#  {'x': 9.5, 'y': 0.9009997844696045, 'z': 7.25},
#  {'x': 9.25, 'y': 0.9009997844696045, 'z': 7.5},
#  {'x': 9.0, 'y': 0.9009997844696045, 'z': 7.75},
#  {'x': 8.75, 'y': 0.9009997844696045, 'z': 8.0},
#  {'x': 8.5, 'y': 0.9009997844696045, 'z': 8.25},
#  {'x': 8.25, 'y': 0.9009997844696045, 'z': 8.5},
#  {'x': 8.0, 'y': 0.9009997844696045, 'z': 8.75},
#  {'x': 7.75, 'y': 0.9009997844696045, 'z': 9.0},
#  {'x': 7.5, 'y': 0.9009997844696045, 'z': 9.25},
#  {'x': 7.25, 'y': 0.9009997844696045, 'z': 9.5},
#  {'x': 7.0, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 6.75, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 6.0, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 5.75, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 5.5, 'y': 0.9009997844696045, 'z': 11.25},
#  {'x': 5.25, 'y': 0.9009997844696045, 'z': 11.5},
#  {'x': 5.0, 'y': 0.9009997844696045, 'z': 11.75},
#  {'x': 4.75, 'y': 0.9009997844696045, 'z': 11.5},
#  {'x': 4.5, 'y': 0.9009997844696045, 'z': 11.25},
#  {'x': 4.25, 'y': 0.9009997844696045, 'z': 11.0},
#  {'x': 4.0, 'y': 0.9009997844696045, 'z': 10.75},
#  {'x': 3.5, 'y': 0.9009997844696045, 'z': 10.25},
#  {'x': 3.25, 'y': 0.9009997844696045, 'z': 10.0},
#  {'x': 3.0, 'y': 0.9009997844696045, 'z': 9.75},
#  {'x': 2.75, 'y': 0.9009997844696045, 'z': 9.5},
#  ...]

# %% [markdown]
# Then we can randomly choose a reachable position and a random rotation, before teleporting the robot to that location:

# %%
import random

position = random.choice(reachable_positions)
rotation = random.choice(range(360))
print("Teleporting the agent to", position, " with rotation", rotation)

event = controller.step(action="Teleport", position=position, rotation=rotation)

Image.fromarray(event.frame)
# Out:
# Teleporting the agent to {'x': 1.25, 'y': 0.9009997844696045, 'z': 7.75}  with rotation 246
# <PIL.Image.Image image mode=RGB size=750x750>

# %% [markdown]
# ## Events

# %% [markdown]
# After each action (eg. "MoveAhead", "RotateRight"...) an `Event` is returned. It contains a lot of information that could be useful for your project. The very first action after you've instantiated the controller is always "CreateHouse". You can access the `Event` data for this action as follows:

# %%
controller.last_event
# Out:
# <ai2thor.server.Event at 0x10e367990
#     .metadata["lastAction"] = Teleport
#     .metadata["lastActionSuccess"] = True
#     .metadata["errorMessage"] = "
#     .metadata["actionReturn"] = None
# >

# %% [markdown]
# We can also get an image of what the most recent scene looks like (i.e. what the robot can see). To do this, we need to use `.frame`. This gives us the RGB frame of the scene, in a numpy array:

# %%
controller.last_event.frame
# Out:
# array([[[ 68,  80, 101],
#         [ 66,  78,  98],
#         [ 69,  80, 101],
#         ...,
#         [ 86,  88, 100],
#         [ 90,  91, 104],
#         [100, 102, 117]],
#
#        [[ 69,  80, 102],
#         [ 66,  77,  98],
#         [ 68,  79, 100],
#         ...,
#         [ 83,  85,  96],
#         [ 93,  95, 109],
#         [105, 107, 123]],
#
#        [[ 70,  81, 104],
#         [ 66,  78,  98],
#         [ 66,  77,  98],
#         ...,
#         [ 97, 100, 114],
#         [114, 117, 134],
#         [117, 120, 139]],
#
#        ...,
#
#        [[ 60,  72,  77],
#         [ 60,  72,  77],
#         [ 60,  72,  77],
#         ...,
#         [ 74,  85, 101],
#         [ 76,  86, 102],
#         [ 76,  87, 102]],
#
#        [[ 60,  72,  77],
#         [ 60,  72,  77],
#         [ 60,  72,  77],
#         ...,
#         [ 76,  86, 102],
#         [ 76,  87, 102],
#         [ 77,  87, 102]],
#
#        [[ 60,  72,  77],
#         [ 60,  72,  77],
#         [ 60,  72,  77],
#         ...,
#         [ 76,  87, 102],
#         [ 77,  87, 102],
#         [ 77,  88, 103]]], dtype=uint8)

# %% [markdown]
# We can also easily turn this numpy array into an image:

# %%
Image.fromarray(controller.last_event.frame)
# Out:
# <PIL.Image.Image image mode=RGB size=750x750>

# %% [markdown]
# One very important type of data you can get from this is the `.metadata`. It contains information on for example the agent's current position and rotation, as well as all objects in the current view, including a lot of object properties. Let's first look at the information about the agent:

# %%
controller.last_event.metadata["agent"]
# Out:
# {'name': 'agent',
#  'position': {'x': 1.25, 'y': 0.9009993672370911, 'z': 7.75},
#  'rotation': {'x': -0.0, 'y': 246.0, 'z': 0.0},
#  'cameraHorizon': 30.00000762939453,
#  'isStanding': True,
#  'inHighFrictionArea': False}

# %% [markdown]
# Now let's look at the objects in the metadata:

# %%
for object in controller.last_event.metadata["objects"]:
  print(object["name"])
# Out:
# Apple|surface|6|33
# ArmChair|7|2|0
# ArmChair|7|3|0
# BasketBall|4|4
# Bed|4|0|0
# Book|surface|4|12
# Book|surface|4|0
# Bottle|surface|6|31
# Bottle|surface|6|28
# Bowl|surface|6|23
# Bowl|surface|7|52
# Box|surface|7|56
# Box|surface|4|16
# Bread|surface|6|51
# Bread|surface|6|22
# ButterKnife|surface|6|44
# ButterKnife|surface|6|37
# ButterKnife|surface|6|38
# Cabinet
# Cabinet
# Cabinet
# Cabinet
# CellPhone|surface|6|32
# CellPhone|surface|4|15
# Chair|6|0|1
# Chair|4|2|1
# Chair|6|0|2
# CounterTop|6|1
# CreditCard|surface|4|7
# CreditCard|surface|6|40
# DeskLamp|surface|4|8
# DiningTable|4|2|0
# DiningTable|6|0|0
# DiningTable|7|0
# DishSponge|surface|5|19
# DogBed|4|3
# door|1|6
# door|4|6
# door|6|7
# door|4|5
# Drawer
# Drawer (1)
# Drawer (2)
# Drawer (3)
# Dresser|4|1
# Egg|surface|6|27
# Egg|surface|6|41
# Egg|surface|6|42
# Faucet|5|1|1
# Floor
# room|7
# room|6
# room|5
# room|4
# FloorLamp|7|2|1
# FloorLamp|7|3|1
# Fork|surface|6|21
# Fridge|6|2
# GarbageCan|5|3
# HousePlant|surface|6|29
# Kettle|surface|6|30
# Kettle|surface|6|43
# Knife|surface|6|47
# Knife|surface|6|45
# Knife|surface|6|46
# Laptop|surface|7|58
# Laptop|surface|4|1
# Microwave|surface|6|34
# Mug|surface|4|9
# Mug|surface|6|26
# Newspaper|surface|7|57
# Painting|7|6
# Painting|6|4
# Painting|5|6
# Painting|6|6
# Painting|7|5
# Painting|5|7
# Painting|4|5
# Painting|6|5
# Painting|4|6
# Painting|5|5
# Pan|surface|6|39
# PaperTowelRoll|surface|6|35
# Pen|surface|7|55
# Pen|surface|4|4
# Pencil|surface|6|50
# Pencil|surface|4|14
# Pencil|surface|4|13
# Pillow|4|0|2
# Pillow|4|0|1
# Plate|surface|7|53
# Plunger|5|2
# RemoteControl|surface|4|6
# SaltShaker|surface|6|49
# Sink|5|1|0
# SinkBasin
# SoapBottle|surface|6|25
# SoapBottle|surface|5|20
# Sofa|7|1
# SprayBottle|surface|6|24
# Statue|surface|4|10
# TeddyBear|surface|4|2
# Television|7|4
# Television|6|3
# TennisRacket|surface|4|17
# TissueBox|surface|4|5
# Toilet|5|0
# ToiletPaper|surface|5|18
# Tomato|surface|6|36
# Tomato|surface|6|48
# Vase|surface|4|11
# wall|6|3.54|5.32|7.09|5.32
# wall|6|0.00|5.32|3.54|5.32
# wall|6|0.00|0.00|0.00|5.32
# wall|5|0.00|5.32|3.54|5.32
# wall|5|3.54|5.32|3.54|12.40
# wall|5|0.00|12.40|3.54|12.40
# wall|5|0.00|5.32|0.00|12.40
# wall|4|7.09|5.32|12.40|5.32
# wall|4|12.40|5.32|12.40|8.86
# wall|4|8.86|8.86|12.40|8.86
# wall|4|8.86|8.86|8.86|12.40
# wall|4|3.54|5.32|3.54|12.40
# wall|4|3.54|12.40|8.86|12.40
# wall|6|7.09|0.00|7.09|5.32
# wall|4|3.54|5.32|7.09|5.32
# wall|6|0.00|0.00|7.09|0.00
# wall|exterior|12.40|0.00|12.40|5.32
# wall|7|7.09|5.32|12.40|5.32
# wall|exterior|7.09|0.00|12.40|0.00
# wall|7|7.09|0.00|7.09|5.32
# wall|exterior|3.54|12.40|8.86|12.40
# wall|exterior|8.86|8.86|12.40|8.86
# wall|exterior|8.86|8.86|8.86|12.40
# wall|exterior|12.40|5.32|12.40|8.86
# wall|exterior|0.00|5.32|0.00|12.40
# wall|exterior|0.00|0.00|0.00|5.32
# wall|exterior|0.00|0.00|7.09|0.00
# wall|7|7.09|0.00|12.40|0.00
# wall|7|12.40|0.00|12.40|5.32
# wall|exterior|0.00|12.40|3.54|12.40
# WashingMachine|5|4
# Watch|surface|7|54
# Watch|surface|4|3
# window|6|0
# window|4|0
# window|4|1
# window|7|0
# window|7|1

# %% [markdown]
# You probably noticed that there are quite a few objects that you cannot actually see if you look at the visualization of the current frame. This is because all objects that are visible (i.e. not hidden behind something) and within the `visibilityDistance` (specified when we initialized the controller) are shown. If you only want the objects that the robot can actually see, you need to only pick objects with `visible=True` (visible being one of the object attributes).

# %%
for object in controller.last_event.metadata["objects"]:
  if object["visible"]:
    print(object["name"])
# Out:
# Painting|5|7
# Toilet|5|0
# wall|5|0.00|5.32|0.00|12.40
# wall|exterior|0.00|5.32|0.00|12.40
# WashingMachine|5|4

# %% [markdown]
# Finally, let's look at what other properties the currently visible objects have:

# %%
for object in controller.last_event.metadata["objects"]:
  if object["visible"]:
    print(object)
# Out:
# {'name': 'Painting|5|7', 'position': {'x': 0.004995772615075111, 'y': 1.4195761680603027, 'z': 7.352122783660889}, 'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}, 'visible': True, 'isInteractable': True, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 1.0, 'salientMaterials': ['Paper', 'Plastic'], 'receptacleObjectIds': None, 'distance': 1.4061520099639893, 'objectType': 'Painting', 'objectId': 'Painting|5|7', 'assetId': 'Wall_Decor_Photo_1', 'parentReceptacles': None, 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[0.03674101084470749, 1.6721744537353516, 7.685946464538574], [0.03674101084470749, 1.6721744537353516, 7.018299102783203], [0.03674101084470749, 1.166977882385254, 7.685946464538574], [0.03674101084470749, 1.166977882385254, 7.018299102783203], [0.00499996542930603, 1.6721744537353516, 7.685946464538574], [0.00499996542930603, 1.6721744537353516, 7.018299102783203], [0.00499996542930603, 1.166977882385254, 7.685946464538574], [0.00499996542930603, 1.166977882385254, 7.018299102783203]], 'center': {'x': 0.02087048813700676, 'y': 1.4195761680603027, 'z': 7.352122783660889}, 'size': {'x': 0.03174104541540146, 'y': 0.5051965713500977, 'z': 0.6676473617553711}}, 'objectOrientedBoundingBox': None}
# {'name': 'Toilet|5|0', 'position': {'x': 0.4974590539932251, 'y': 0.0017688274383544922, 'z': 5.6048994064331055}, 'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}, 'visible': True, 'isInteractable': True, 'receptacle': True, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': True, 'isOpen': False, 'openness': 0.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 0.0, 'salientMaterials': None, 'receptacleObjectIds': ['ToiletPaper|surface|5|18'], 'distance': 2.4446656703948975, 'objectType': 'Toilet', 'objectId': 'Toilet|5|0', 'assetId': 'Toilet_1', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[0.997867226600647, 1.0379130840301514, 5.869483947753906], [0.997867226600647, 1.0379130840301514, 5.340000152587891], [0.997867226600647, 2.384185791015625e-07, 5.869483947753906], [0.997867226600647, 2.384185791015625e-07, 5.340000152587891], [0.02499997615814209, 1.0379130840301514, 5.869483947753906], [0.02499997615814209, 1.0379130840301514, 5.340000152587891], [0.02499997615814209, 2.384185791015625e-07, 5.869483947753906], [0.02499997615814209, 2.384185791015625e-07, 5.340000152587891]], 'center': {'x': 0.5114336013793945, 'y': 0.5189566612243652, 'z': 5.604742050170898}, 'size': {'x': 0.9728672504425049, 'y': 1.0379128456115723, 'z': 0.5294837951660156}}, 'objectOrientedBoundingBox': None}
# {'name': 'wall|5|0.00|5.32|0.00|12.40', 'position': {'x': 0.0, 'y': 1.4842236042022705, 'z': 8.858500480651855}, 'rotation': {'x': -0.0, 'y': 270.0, 'z': 0.0}, 'visible': True, 'isInteractable': True, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 0.0, 'salientMaterials': None, 'receptacleObjectIds': None, 'distance': 1.769582986831665, 'objectType': 'Wall', 'objectId': 'wall|5|0.00|5.32|0.00|12.40', 'assetId': '', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[5.416275712377683e-07, 2.968447685241699, 12.402002334594727], [5.416275712377683e-07, 2.968447685241699, -1.9073486328125e-06], [5.416275712377683e-07, -4.76837158203125e-07, 12.402002334594727], [5.416275712377683e-07, -4.76837158203125e-07, -1.9073486328125e-06], [-5.416275712377683e-07, 2.968447685241699, 12.402002334594727], [-5.416275712377683e-07, 2.968447685241699, -1.9073486328125e-06], [-5.416275712377683e-07, -4.76837158203125e-07, 12.402002334594727], [-5.416275712377683e-07, -4.76837158203125e-07, -1.9073486328125e-06]], 'center': {'x': 0.0, 'y': 1.4842236042022705, 'z': 6.201000213623047}, 'size': {'x': 1.0832551424755366e-06, 'y': 2.9684481620788574, 'z': 12.40200424194336}}, 'objectOrientedBoundingBox': None}
# {'name': 'wall|exterior|0.00|5.32|0.00|12.40', 'position': {'x': 0.0, 'y': 1.4842236042022705, 'z': 8.858500480651855}, 'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}, 'visible': True, 'isInteractable': True, 'receptacle': False, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': False, 'isPickedUp': False, 'moveable': False, 'mass': 0.0, 'salientMaterials': None, 'receptacleObjectIds': None, 'distance': 1.769582986831665, 'objectType': 'Wall', 'objectId': 'wall|exterior|0.00|5.32|0.00|12.40', 'assetId': '', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[5.416275712377683e-07, 2.968447685241699, 12.402002334594727], [5.416275712377683e-07, 2.968447685241699, -1.9073486328125e-06], [5.416275712377683e-07, -4.76837158203125e-07, 12.402002334594727], [5.416275712377683e-07, -4.76837158203125e-07, -1.9073486328125e-06], [-5.416275712377683e-07, 2.968447685241699, 12.402002334594727], [-5.416275712377683e-07, 2.968447685241699, -1.9073486328125e-06], [-5.416275712377683e-07, -4.76837158203125e-07, 12.402002334594727], [-5.416275712377683e-07, -4.76837158203125e-07, -1.9073486328125e-06]], 'center': {'x': 0.0, 'y': 1.4842236042022705, 'z': 6.201000213623047}, 'size': {'x': 1.0832551424755366e-06, 'y': 2.9684481620788574, 'z': 12.40200424194336}}, 'objectOrientedBoundingBox': None}
# {'name': 'WashingMachine|5|4', 'position': {'x': 0.3657973110675812, 'y': 0.0015662312507629395, 'z': 8.661118507385254}, 'rotation': {'x': -0.0, 'y': 90.0, 'z': -0.0}, 'visible': True, 'isInteractable': True, 'receptacle': True, 'toggleable': False, 'isToggled': False, 'breakable': False, 'isBroken': False, 'canFillWithLiquid': False, 'isFilledWithLiquid': False, 'fillLiquid': None, 'dirtyable': False, 'isDirty': False, 'canBeUsedUp': False, 'isUsedUp': False, 'cookable': False, 'isCooked': False, 'temperature': 'RoomTemp', 'isHeatSource': False, 'isColdSource': False, 'sliceable': False, 'isSliced': False, 'openable': False, 'isOpen': False, 'openness': 0.0, 'pickupable': False, 'isPickedUp': False, 'moveable': True, 'mass': 1.0, 'salientMaterials': [], 'receptacleObjectIds': [], 'distance': 1.555934190750122, 'objectType': 'WashingMachine', 'objectId': 'WashingMachine|5|4', 'assetId': 'Washing_Machine_1', 'parentReceptacles': ['Floor'], 'controlledObjects': None, 'isMoving': False, 'axisAlignedBoundingBox': {'cornerPoints': [[0.7043943405151367, 1.1449742317199707, 8.998199462890625], [0.7043943405151367, 1.1449742317199707, 8.323671340942383], [0.7043943405151367, 2.384185791015625e-07, 8.998199462890625], [0.7043943405151367, 2.384185791015625e-07, 8.323671340942383], [0.025000154972076416, 1.1449742317199707, 8.998199462890625], [0.025000154972076416, 1.1449742317199707, 8.323671340942383], [0.025000154972076416, 2.384185791015625e-07, 8.998199462890625], [0.025000154972076416, 2.384185791015625e-07, 8.323671340942383]], 'center': {'x': 0.36469724774360657, 'y': 0.5724872350692749, 'z': 8.660935401916504}, 'size': {'x': 0.6793941855430603, 'y': 1.1449739933013916, 'z': 0.6745281219482422}}, 'objectOrientedBoundingBox': {'cornerPoints': [[0.7043943405151367, 2.384185791015625e-07, 8.323671340942383], [0.7043942809104919, 2.384185791015625e-07, 8.998199462890625], [0.025000154972076416, 2.384185791015625e-07, 8.998199462890625], [0.02500021457672119, 2.384185791015625e-07, 8.323671340942383], [0.7043943405151367, 1.1449742317199707, 8.323671340942383], [0.7043942809104919, 1.1449742317199707, 8.998199462890625], [0.025000154972076416, 1.1449742317199707, 8.998199462890625], [0.02500021457672119, 1.1449742317199707, 8.323671340942383]]}}

# %% [markdown]
# When done with the interaction, you should stop the ```controller```, which closes the AI2Thor viewer.

# %%
controller.stop()

# %% [markdown]
# ## End of notebook
