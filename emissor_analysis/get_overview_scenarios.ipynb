# %% [markdown]
# # Getting an overview of the EMISSOR scenarios
#
# This notebook shows how you get an overview of the scenarios in your EMISSOR folder.

# %% [markdown]
# The notebook requires the ```emissor``` package that you can install through pip.

# %%
#!pip install emissor

# %%
from datetime import datetime
import os
from emissor.persistence import ScenarioStorage
from emissor.persistence.persistence import ScenarioController
from emissor.processing.api import SignalProcessor
from emissor.representation.scenario import Modality, Signal, TextSignal

# %% [markdown]
# ## Load the different scenarios from the EMISSOR folder

# %%
emissor = "../../home/lmc/combot/storage/emissor"
scenario = []
# Get list of scenarios from the emissor path
try:
    scenarios = [f for f in os.listdir(emissor) if os.path.isdir(os.path.join(emissor, f))]
    print(f'There are %s scenarios are:', len(scenarios))
except FileNotFoundError:
    print(f"Error: The path '{emissor}' does not exist.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# There are %s scenarios are: 68

# %% [markdown]
# ## Getting meta data and sginals from a scenario

# %% [markdown]
# The next functions 1) read the meta data from the scenario JSON file and the signals from the text and image JSON files.

# %%
def get_date_duration_in_minutes(scenario_ctrl):
    start = 0
    end = 0
    duration = 0
    date = None
    try:
        start = int(scenario_ctrl.scenario.start)
        end = int(scenario_ctrl.scenario.end)
        date = datetime.fromtimestamp(start/1000).strftime('%Y-%m-%d')
    except:
        print(f'\tError getting duration: start={scenario_ctrl.scenario.start}, end={scenario_ctrl.scenario.end}')
    if start>0 and end>0:
        duration = (end - start) / 60000
    return date, duration
    
def get_meta_data (emissor_folder:str, scenario_id:str):
    scenario_folder = os.path.join(emissor_folder, scenario_id)
    scenario_storage = ScenarioStorage(emissor_folder)
    scenario_ctrl = scenario_storage.load_scenario(scenario_id)
    speaker = "No speaker"
    agent = "No agent"
    location = "No location"
    people = "Not in context"
    objects = "Not in context"
    duration = 0
    try:
        speaker = scenario_ctrl.scenario.context.speaker["name"] if "name" in scenario_ctrl.scenario.context.speaker else "No speaker"
    except:
        print("\tNo speaker in context")
    try:
        agent = scenario_ctrl.scenario.context.agent["name"] if "name" in scenario_ctrl.scenario.context.agent else "No agent"
    except:
        print("\tNo speaker in context")
    try:
        location = scenario_ctrl.scenario.context.location_id  #### Change this to location name when this implemented
    except:
        print("\tNo location id in context")
    try:
        people = scenario_ctrl.scenario.context.persons
    except:
        print("\tNo location id in context")
    try:
        objects = scenario_ctrl.scenario.context.objects
    except:
        print("\tNo location id in context")
    date, duration = get_date_duration_in_minutes(scenario_ctrl)
    return speaker, agent, location, people, objects, date, duration

def get_text_signals_from_a_scenario(emissor_folder:str, scenario_id:str):
    text_signals=[]
    scenario_folder = os.path.join(emissor_folder, scenario_id)
    scenario_storage = ScenarioStorage(emissor_folder)
    scenario_ctrl = scenario_storage.load_scenario(scenario_id)
    try:
        text_signals = scenario_ctrl.get_signals(Modality.TEXT)
    except:
        print('Error loading text signals from text.json')
    return text_signals

def get_image_signals_from_a_scenario(emissor_folder:str, scenario_id:str):
    text_signals=[]
    scenario_folder = os.path.join(emissor_folder, scenario_id)
    scenario_storage = ScenarioStorage(emissor_folder)
    scenario_ctrl = scenario_storage.load_scenario(scenario_id)
    try:
        text_signals = scenario_ctrl.get_signals(Modality.IMAGE)
    except:
        print('Error loading image signals from text.json')
    return text_signals

# %% [markdown]
# The next loop will get the basic information for each scenario and print the result:

# %%
cnt_valid = 0
for scenario in scenarios:
    rdf_folder = os.path.join(emissor, scenario, "rdf")
    speaker, agent, location, people, objects, date, duration = get_meta_data(emissor, scenario)
    text_signals = get_text_signals_from_a_scenario(emissor, scenario)
    image_signals = get_image_signals_from_a_scenario(emissor, scenario)
    if len(text_signals)>0:
        if os.path.exists(rdf_folder):
            cnt_valid +=1
            print(f"scenario={scenario}")
            print(f"\tdate={str(date)}, duration in minutes={round(duration, 2)}")
            print(f"\tspeaker={speaker}, agent={agent}, seen people={people}, seen objects={objects}, text signals={len(text_signals)}, image signals={len(image_signals)}")
            print()

print("Valid interactions:", cnt_valid)
# Out:
# scenario=ddbc4bd5-4c93-4436-94bc-9d72c3b57c06
# 	date=2025-11-12, duration in minutes=50.07
# 	speaker=Angus, agent=Leolani, seen people=[], seen objects=[], text signals=114, image signals=0
#
# 	Error getting duration: start=1762359400211, end=None
# 	Error getting duration: start=1762953318535, end=None
# 	Error getting duration: start=1762953462003, end=None
# scenario=028be0d0-df6a-4b70-9315-6c38a0e9a78c
# 	date=2025-11-05, duration in minutes=3.69
# 	speaker=Human, agent=Leolani, seen people=[], seen objects=[], text signals=21, image signals=0
#
# scenario=1b06b9d5-2317-4bc4-b0a2-0fddc446b9bb
# 	date=2025-11-18, duration in minutes=2.59
# 	speaker=yasemin, agent=Leolani, seen people=[], seen objects=[], text signals=5, image signals=0
#
# 	Error getting duration: start=1762363389210, end=None
# 	Error getting duration: start=1763051075777, end=None
# 	Error getting duration: start=1762957088353, end=None
# 	Error getting duration: start=1762514542876, end=None
# 	Error getting duration: start=1762866890979, end=None
# scenario=48993dba-592a-4c60-8829-da2ad5a7da31
# 	date=2025-11-16, duration in minutes=40.36
# 	speaker=Susan, agent=Leolani, seen people=[], seen objects=[], text signals=97, image signals=0
#
# 	Error getting duration: start=1762952359458, end=None
# 	Error getting duration: start=1762523241502, end=None
# 	Error getting duration: start=1762523267378, end=None
# 	Error getting duration: start=1763476604847, end=None
# scenario=b5d13433-a4ba-4706-a3a1-69c3ca9c3f0e
# 	date=2025-11-12, duration in minutes=3.66
# 	speaker=Arthur, agent=Leolani, seen people=[], seen objects=[], text signals=9, image signals=0
#
# 	Error getting duration: start=1762937695583, end=None
# 	Error getting duration: start=1762523700060, end=None
# 	Error getting duration: start=1762951585068, end=None
# 	Error getting duration: start=1762525129251, end=None
# 	Error getting duration: start=1762867670740, end=None
# scenario=65d0501b-619b-47d2-a8a4-c86f3e2f29f2
# 	date=2025-11-16, duration in minutes=2.33
# 	speaker=Susan, agent=Leolani, seen people=[], seen objects=[], text signals=9, image signals=0
#
# 	Error getting duration: start=1762524054651, end=None
# scenario=92c22ff4-bbb5-454f-987d-8d32322c1baa
# 	date=2025-11-07, duration in minutes=2.62
# 	speaker=Piek, agent=Leolani, seen people=[], seen objects=[], text signals=7, image signals=0
#
# scenario=d6765e31-13ab-4e8d-baef-5966f9f8df87
# 	date=2025-11-11, duration in minutes=1.62
# 	speaker=Susan, agent=Leolani, seen people=[], seen objects=[], text signals=11, image signals=0
#
# 	Error getting duration: start=1762949587912, end=None
# 	Error getting duration: start=1762956967214, end=None
# 	Error getting duration: start=1762501791983, end=None
# 	Error getting duration: start=1762502934768, end=None
# 	Error getting duration: start=1762953689460, end=None
# scenario=1964dbd8-ad12-4a89-8169-4b5754399dc7
# 	date=2025-11-12, duration in minutes=7.46
# 	speaker=Yannis, agent=Leolani, seen people=[], seen objects=[], text signals=27, image signals=0
#
# 	Error getting duration: start=1762953870296, end=None
# 	Error getting duration: start=1762952671397, end=None
# 	Error getting duration: start=1762516951800, end=None
# 	Error getting duration: start=1762960309869, end=None
# 	Error getting duration: start=1762937913826, end=None
# 	Error getting duration: start=1762952834879, end=None
# 	Error getting duration: start=1762516415356, end=None
# 	Error getting duration: start=1762952740108, end=None
# 	Error getting duration: start=1762951958243, end=None
# 	Error getting duration: start=1762938460835, end=None
# 	Error getting duration: start=1763051341822, end=None
# 	Error getting duration: start=1763400640756, end=None
# 	Error getting duration: start=1762425995886, end=None
# scenario=c75f44a4-fafa-47dd-b97e-5ba05fca3ba3
# 	date=2025-11-12, duration in minutes=1.5
# 	speaker=Adele, agent=Leolani, seen people=[], seen objects=[], text signals=8, image signals=0
#
# 	Error getting duration: start=1762523568616, end=None
# scenario=44814425-6eb2-46a5-aec6-66929d16ba82
# 	date=2025-11-07, duration in minutes=12.04
# 	speaker=Fred, agent=Leolani, seen people=[], seen objects=[], text signals=25, image signals=0
#
# 	Error getting duration: start=1762516255109, end=None
# 	Error getting duration: start=1762514192801, end=None
# 	Error getting duration: start=1762515522994, end=None
# scenario=988c0d27-765c-47f7-9326-1c8ec57892b6
# 	date=2025-11-12, duration in minutes=5.6
# 	speaker=Arthur, agent=Leolani, seen people=[], seen objects=[], text signals=14, image signals=0
#
# 	Error getting duration: start=1763327791461, end=None
# 	Error getting duration: start=1762938987411, end=None
# scenario=63f890c0-b231-4d12-8fe2-d265f1a4104c
# 	date=2025-11-16, duration in minutes=0.93
# 	speaker=Susan, agent=Leolani, seen people=[], seen objects=[], text signals=4, image signals=0
#
# 	Error getting duration: start=1763400063208, end=None
# 	Error getting duration: start=1762523560170, end=None
# 	Error getting duration: start=1762515136603, end=None
# scenario=43f0f461-79d8-4c94-be59-321fd6de1c4e
# 	date=2025-11-12, duration in minutes=0.63
# 	speaker=Yannis, agent=Leolani, seen people=[], seen objects=[], text signals=5, image signals=0
#
# 	Error getting duration: start=1763323634544, end=None
# 	Error getting duration: start=1762958783104, end=None
# 	Error getting duration: start=1762517808286, end=None
# 	Error getting duration: start=1762953848425, end=None
# scenario=8bbc592e-80e3-483c-a611-459be489b599
# 	date=2025-11-07, duration in minutes=23.38
# 	speaker=John, agent=Leolani, seen people=[], seen objects=[], text signals=35, image signals=0
#
# scenario=f8f2722f-b373-4d5e-b241-395c1edfa34e
# 	date=2025-11-12, duration in minutes=3.11
# 	speaker=Marie, agent=Leolani, seen people=[], seen objects=[], text signals=7, image signals=0
#
# 	Error getting duration: start=1762523523087, end=None
# 	Error getting duration: start=1762952677745, end=None
# 	Error getting duration: start=1762517202633, end=None
# Valid interactions: 16

# %%
cnt_rdf = 0
cnt_text = 0
for scenario in scenarios:
    rdf_folder = os.path.join(emissor, scenario, "rdf")
    speaker, agent, location, people, objects, date, duration = get_meta_data(emissor, scenario)
    text_signals = get_text_signals_from_a_scenario(emissor, scenario)
    image_signals = get_image_signals_from_a_scenario(emissor, scenario)
    if len(text_signals)>0:
        if not os.path.exists(rdf_folder):
            cnt_rdf+=1
            print(f"scenario={scenario}")
            print(f"\tspeaker={speaker}")
            print(f"\tdate={str(date)}, duration in minutes={round(duration, 2)}")
            print("\tNO triples extracted")
            print()
    else:
        cnt_text +=1
        print(f"scenario={scenario}")
        print(f"\tspeaker={speaker}")
        print(f"\tdate={str(date)}, duration in minutes={round(duration, 2)}")
        print("\tNO conversation started")
        print()

print("No RDF:", cnt_rdf)
print("No text:", cnt_text)
# Out:
# 	Error getting duration: start=1762359400211, end=None
# scenario=fadf8300-5424-45c2-b60d-790aff897c6f
# 	speaker=Human
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762953318535, end=None
# scenario=e66527d0-2939-4db2-92e1-697044d83790
# 	speaker=Estelle
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762953462003, end=None
# scenario=02b1ee0a-8a0b-4760-b56c-8fa7ad4af0cd
# 	speaker=Arthur
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762363389210, end=None
# scenario=677b55fe-f198-45c1-9d74-a2c62613d15a
# 	speaker=Human
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1763051075777, end=None
# scenario=c0aa7291-e759-4ee5-bf50-f985bac4e552
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762957088353, end=None
# scenario=11c7acae-2b24-408f-a0c3-23b4c15d5dde
# 	speaker=Yannis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762514542876, end=None
# scenario=6b76d810-0d8d-4688-86cc-17aa664e57b4
# 	speaker=Piek
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762866890979, end=None
# scenario=1a093e5d-370d-479b-a2de-ed6e3f25538c
# 	speaker=Susan
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762952359458, end=None
# scenario=81080a7d-f9f6-40c3-af9e-ecbd4f8ba1e0
# 	speaker=H
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762523241502, end=None
# scenario=32d2c339-9e55-49dc-9ebb-28bf8537a6c9
# 	speaker=Timo
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762523267378, end=None
# scenario=cd1810bb-8280-4ad2-aca4-6d6a99efc699
# 	speaker=Hans
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763476604847, end=None
# scenario=d7d3c694-7067-44df-b865-44320d9ba9cc
# 	speaker=yasemin
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762937695583, end=None
# scenario=76fc8299-9785-453a-823b-dce55bd7224a
# 	speaker=Fred
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762523700060, end=None
# scenario=78349f9a-a64b-4540-a020-d94bcba62e24
# 	speaker=Timo
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762951585068, end=None
# scenario=c4533cf1-ac75-4355-9168-ef969a427c5c
# 	speaker=Rosa
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762525129251, end=None
# scenario=e1b6c3e5-d526-47ec-9d59-6ebff1f64402
# 	speaker=John
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762867670740, end=None
# scenario=3a39d581-1ca5-4e74-917d-704d216ba574
# 	speaker=Susan
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762524054651, end=None
# scenario=6a60d6c9-4868-4c9f-a5c4-a68f3ee4aaa5
# 	speaker=Henry
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762949587912, end=None
# scenario=ea93d4ef-fc73-442f-ac5f-b29105338628
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762956967214, end=None
# scenario=b697087f-0767-4d0d-b1aa-74312c1bf9c7
# 	speaker=Angus
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762501791983, end=None
# scenario=bbcc495a-985a-47ab-ae4f-73ddd1e2db54
# 	speaker=Piek
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762502934768, end=None
# scenario=56f596b4-c123-468b-9841-50e962b28e37
# 	speaker=Piek
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762953689460, end=None
# scenario=36cace38-2405-4ac7-a71a-3070b5ee7535
# 	speaker=Shavi
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762953870296, end=None
# scenario=5f802e8b-d100-427b-a782-851dbe169c8c
# 	speaker=Yannis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762952671397, end=None
# scenario=1d88aad3-959f-4daf-83a2-28d840b5be09
# 	speaker=Yannis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762516951800, end=None
# scenario=ec19fa9d-f0c2-4cce-b8ed-4d81ac91c57e
# 	speaker=Piek
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762960309869, end=None
# scenario=a0eda18f-76ee-4b57-9867-304d5e8e2af5
# 	speaker=Castor
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762937913826, end=None
# scenario=5a4f1ad7-7d97-4a3f-94a8-44a5e89c1db1
# 	speaker=Castor
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762952834879, end=None
# scenario=1fab620c-5d63-4ee4-84f1-0364716b89a6
# 	speaker=Arthur
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762516415356, end=None
# scenario=69e405e0-2378-4d89-ad76-828058752ca0
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762952740108, end=None
# scenario=e9dc262c-0da1-46b3-a76f-c59ddaeed9d4
# 	speaker=Manya
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762951958243, end=None
# scenario=4a271280-b5de-4763-8622-d1025e166858
# 	speaker=J
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762938460835, end=None
# scenario=3cbae031-d406-4cb6-a10e-c6bb6f76f81a
# 	speaker=Castor
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763051341822, end=None
# scenario=d08fcdb0-6183-436f-899f-d7d0515bbc7e
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763400640756, end=None
# scenario=823bb4c2-4475-4f00-9d96-52be15b4b66d
# 	speaker=Bob
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762425995886, end=None
# scenario=0bf1625c-0ae9-4b09-a787-7798ae1cf627
# 	speaker=Human
# 	date=None, duration in minutes=0
# 	NO conversation started
#
# 	Error getting duration: start=1762523568616, end=None
# scenario=ed975b2d-f02f-405a-92f3-5fd043a2a2ed
# 	speaker=Timo
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762516255109, end=None
# scenario=1d50e26b-6355-402d-8d23-c2c2cfe7ea6d
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762514192801, end=None
# scenario=c49010e5-c10b-4216-b14c-8acb58f1e2a5
# 	speaker=Human
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762515522994, end=None
# scenario=347d9124-f2bf-4882-8390-f3b71f23296e
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763327791461, end=None
# scenario=3bbbc4ef-7bc8-4a76-80c3-d18038916112
# 	speaker=Susan
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762938987411, end=None
# scenario=a516fead-e275-42ec-8310-08d51e5a2ca7
# 	speaker=Castor
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763400063208, end=None
# scenario=7642d571-0236-4ddb-b011-70c08f471fa6
# 	speaker=Joe
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762523560170, end=None
# scenario=b836b075-9d17-482f-aea1-f3cac59fb10f
# 	speaker=Fred
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762515136603, end=None
# scenario=7738f6c4-763f-4a56-bc6f-bb1dab25ea7d
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1763323634544, end=None
# scenario=ad47415c-f4d6-47c2-8507-bafc6c29eb50
# 	speaker=Susan
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762958783104, end=None
# scenario=f98093bf-39e5-4a19-998b-b86e08b2b6a5
# 	speaker=Castor
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762517808286, end=None
# scenario=aa8220b8-3f92-4376-9113-da6be27b69b9
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762953848425, end=None
# scenario=20c26742-8c6d-4ea1-9e07-a05e17a97b0d
# 	speaker=Marie
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762523523087, end=None
# scenario=772b838b-7755-4fdc-a59d-e9fbc3aa1ac9
# 	speaker=Fred
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762952677745, end=None
# scenario=37c7a5c2-357a-49d8-a3e3-27af3b4225d7
# 	speaker=Adele
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# 	Error getting duration: start=1762517202633, end=None
# scenario=b387db06-934e-405b-9d4e-f7e5c27b440a
# 	speaker=Luis
# 	date=None, duration in minutes=0
# 	NO triples extracted
#
# No RDF: 45
# No text: 7

# %% [markdown]
# ## Getting the conversation from a scenario

# %% [markdown]
# The next function gets the speaker from each Text Signal. If the value is ```value='SPEAKER'``` it is the speaker that is set in the scenario meta data.

# %%
def get_speaker_from_text_signal(textSignal: TextSignal):
    speaker = None
    mentions = textSignal.mentions
    for mention in mentions:
        annotations = mention.annotations
        for annotation in annotations:
            if annotation.type == 'ConversationalAgent':
                speaker = annotation.value
                break
        if speaker:
            break
    return speaker

# %%
scenario = "b387db06-934e-405b-9d4e-f7e5c27b440a"
speaker, agent, _, _, _, _, _ = get_meta_data(emissor, scenario)
# print(speaker, agent)
text_signals = get_text_signals_from_a_scenario(emissor, scenario)
for text_signal in text_signals:
    signal_speaker = ""
    signal_speaker = get_speaker_from_text_signal(text_signal)
    if signal_speaker=='SPEAKER':
        signal_speaker = speaker
    else:
        signal_speaker = agent
    print(signal_speaker, ":", text_signal.text)
# Out:
# 	Error getting duration: start=1762517202633, end=None
# Leolani : Yo Do you want to talk to me Luis?
# Luis : Yes
# Leolani : I have nothing more to say.
# Luis : I live in Amstelveen.
# Leolani : Has Luis visited the agent?
# Luis : I visited Piek.
# Luis : Do you know Piek?
# Leolani : Ik wil het weten. Heeft Luis muzikale werken?
# Leolani : Someone said that I know Piek.

# %%
scenario = "0985799c-80eb-416c-b55e-f11ffc4ac259"
speaker, agent, _, _, _, _, _ = get_meta_data(emissor, scenario)
# print(speaker, agent)
text_signals = get_text_signals_from_a_scenario(emissor, scenario)
for text_signal in text_signals:
    signal_speaker = ""
    signal_speaker = get_speaker_from_text_signal(text_signal)
    if signal_speaker=='SPEAKER':
        signal_speaker = speaker
    else:
        signal_speaker = agent
    print(signal_speaker, ":", text_signal.text)
# Out:
# 	No location id in context
# 	No location id in context
# 	No location id in context
# Ai2Thor : Hi Piek. Tell me what to do.
# Ai2Thor : This is what I can do:('I can do the following:', "['find', 'describe', 'move', 'go', 'turn', 'forward', 'back', 'left', 'right', 'open', 'close', 'look']")
# Ai2Thor : forward
# Ai2Thor : move forward
# Ai2Thor : MoveAhead
# Ai2Thor : what do you see.
# Ai2Thor : Sorry I do not get that:what
# Ai2Thor : look
# Ai2Thor : describe
# Ai2Thor : I see 67 things there.
# Apple
# Bottle
# 	I can break it.
# Bowl
# Bread
# ButterKnife
# Cabinet
# 	I can open it.
# Cabinet
# 	I can open it.
# Cabinet
# 	I can open it.
# Cabinet
# 	I can open it.
# Cabinet
# 	I can open it.
# Cabinet
# 	I can open it.
# CellPhone
# 	I can break it.
# Chair
# 	I can move it.
# Chair
# 	I can move it.
# CoffeeMachine
# 	I can move it.
# CounterTop
# CounterTop
# CounterTop
# CreditCard
# Cup
# 	I can break it.
# DishSponge
# Drawer
# 	I can open it.
# Drawer
# 	I can open it.
# Drawer
# 	I can open it.
# Egg
# 	I can break it.
# Faucet
# Floor
# Fork
# Fridge
# 	I can open it.
# GarbageCan
# 	I can move it.
# HousePlant
# 	I can move it.
# Knife
# Lettuce
# LightSwitch
# Microwave
# 	I can move it.
# 	I can open it.
# Mug
# 	I can break it.
# Pan
# PaperTowelRoll
# PepperShaker
# Plate
# 	I can break it.
# Pot
# Potato
# SaltShaker
# Shelf
# Shelf
# Shelf
# ShelvingUnit
# 	I can move it.
# Sink
# SinkBasin
# SoapBottle
# Spatula
# Spoon
# Statue
# 	I can break it.
# StoveBurner
# StoveBurner
# StoveBurner
# StoveBurner
# StoveKnob
# StoveKnob
# StoveKnob
# StoveKnob
# Toaster
# 	I can move it.
# Tomato
# Vase
# 	I can break it.
# Vase
# 	I can break it.
# Window
# 	I can break it.
# Window
# 	I can break it.
#
# Ai2Thor : bye
# Ai2Thor : Hi Piek. Tell me what to do.
# Ai2Thor : This is what I can do:('I can do the following:', "['find', 'describe', 'move', 'go', 'turn', 'forward', 'back', 'left', 'right', 'open', 'close', 'look']")
# Ai2Thor : find spoon
# Ai2Thor : I found 1 instances of type spoon in my view
# Spoon_4a610c23 at {'x': -1.2419390678405762, 'y': 0.9198877215385437, 'z': -1.2094093561172485}
# Ai2Thor : Look
# Ai2Thor : move forward
# Ai2Thor : MoveAhead
# Ai2Thor : turn left
# Ai2Thor : RotateLeft
# Ai2Thor : find apple
# Ai2Thor : I found 1 instances of type apple in my view
# Apple_f33eaaa0 at {'x': -1.0949554443359375, 'y': 0.9632999897003174, 'z': -0.01994890719652176}
# Ai2Thor : Look
# Ai2Thor : bye

# %% [markdown]
# ## End of notebook
